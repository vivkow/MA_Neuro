# %% [markdown]
# This notebook cleans the data retrieved from KB long-term-stable data set versions. Duplicates are removed and the data is saved in a new file. The item_ids are saved for the future reference retrieval. In a following notebook, the data is preliminarily analyzed and visualized.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns
#import re
#import numpy as np
#import matplotlib as mpl

# Fonts for plots
#mpl.rcParams['font.serif'] = 'Times New Roman'
#plt.rcParams['font.family'] = 'serif'

#pd.set_option('display.max_columns', None)

# Path to data retrieval and storage
path = "C:/Users/kleinow/ownCloud/MA_Neuro"

# %%
# Load KB data; 12 data frames
# cn1 indicates "computational neuroscience", whereas cn2 indicates "computational neurosciences" (note the -s)

# CompNeuro found in keyword section 
cn1 = pd.read_csv(path + '/cn1.csv')
cn2 = pd.read_csv(path + '/cn2.csv')

#CompNeuro found in title section
cn1_t = pd.read_csv(path + '/cn1_titles.csv')
cn2_t = pd.read_csv(path + '/cn2_titles.csv')

#CompNeuro found in abstract section
cn1_abs = pd.read_csv(path + '/cn1_abs.csv')
cn2_abs = pd.read_csv(path + '/cn2_abs.csv')

# Corresponding abstract retrieval for each of the data frames above
cn1_abstracts = pd.read_csv(path + '/cn1_abstracts.csv')
cn2_abstracts = pd.read_csv(path + '/cn2_abstracts.csv')
cn1_t_abstracts = pd.read_csv(path + '/cn1_titles_abstracts.csv')
cn2_t_abstracts = pd.read_csv(path + '/cn2_titles_abstracts.csv')
cn1_abs_abstracts = pd.read_csv(path + '/cn1_abs_abstracts.csv')
cn2_abs_abstracts = pd.read_csv(path + '/cn2_abs_abstracts.csv')

# %%
# Merge abstracts to data frames
# Attention: Contrary to the KB overview, the abstract column is called "abstract" here, not "abstract_text"
cn1 = cn1.merge(cn1_abstracts[['item_id', 'abstract']], on='item_id', how='left')
cn2 = cn2.merge(cn2_abstracts[['item_id', 'abstract']], on='item_id', how='left')

cn1_t = cn1_t.merge(cn1_t_abstracts[['item_id', 'abstract']], on='item_id', how='left')
cn2_t = cn2_t.merge(cn2_t_abstracts[['item_id', 'abstract']], on='item_id', how='left')

cn1_abs = cn1_abs.merge(cn1_abs_abstracts[['item_id', 'abstract']], on='item_id', how='left')
cn2_abs = cn2_abs.merge(cn2_abs_abstracts[['item_id', 'abstract']], on='item_id', how='left')

# %%
# Append the cn2 data frames to the cn1 data frames and remove occuring duplicates
cn = cn1.append(cn2).drop_duplicates().reset_index(drop=True) # method chaining
cn_t = cn1_t.append(cn2_t).drop_duplicates().reset_index(drop=True)
cn_abs = cn1_abs.append(cn2_abs).drop_duplicates().reset_index(drop=True)

# Comparison of the length of the data frames
lengths = {
    "DataFrame": ["cn1", "cn2", "cn_combined", "cn1_t", "cn2_t", "cn_t_combined", "cn1_abs", "cn2_abs", "cn_abs_combined"],
    "Length": [
        len(cn1), len(cn2), len(cn),
        len(cn1_t), len(cn2_t), len(cn_t),
        len(cn1_abs), len(cn2_abs), len(cn_abs)
    ]
}

length_df = pd.DataFrame(lengths)
length_df
# Out:
# C:\Users\kleinow\AppData\Local\Temp\ipykernel_22760\2455577134.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cn = cn1.append(cn2).drop_duplicates().reset_index(drop=True) # method chaining
# C:\Users\kleinow\AppData\Local\Temp\ipykernel_22760\2455577134.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cn_t = cn1_t.append(cn2_t).drop_duplicates().reset_index(drop=True)
# C:\Users\kleinow\AppData\Local\Temp\ipykernel_22760\2455577134.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cn_abs = cn1_abs.append(cn2_abs).drop_duplicates().reset_index(drop=True)
#          DataFrame  Length
# 0              cn1     705
# 1              cn2      11
# 2      cn_combined     716
# 3            cn1_t      72
# 4            cn2_t       0
# 5    cn_t_combined      72
# 6          cn1_abs     903
# 7          cn2_abs      22
# 8  cn_abs_combined     924

# %% [markdown]
# Note: There were entirely no finds for "computational neurosciences" in the title section of the KB search results.

# %%
# Merge the results for keyword section, title, and abstract
cn_full = cn.append([cn_t, cn_abs]).drop_duplicates().reset_index(drop=True)
cn_full.shape # (1587, 51)
# Out:
# C:\Users\kleinow\AppData\Local\Temp\ipykernel_22760\3540281187.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cn_full = cn.append([cn_t, cn_abs]).drop_duplicates().reset_index(drop=True)
# (1587, 51)

# %% [markdown]
# By merging the results for the keyword section, title and abstract, we get a data frame with 1587 entries. During the merging process, 125 publications have been removed from the otherwise combined 1712 publications.

# %%
# Add a column with the title in lower case
cn_full['title_lower'] = cn_full['item_title'].str.lower()
cn_full.title_lower.nunique() # only 1552 unique titles

duplicated_mask = cn_full['title_lower'].duplicated(keep=False) # keep = False marks all duplicates as True, not just the subsequent ones after the first occurrence

non_unique = cn_full[duplicated_mask]
non_unique # shows all the duplicated titles
# Out:
#                   item_id fk_repository_history pubyear  pubmonth  \
# 32    WOS:000389557000015              52378983    2016      10.0
# 177   WOS:000184147100024              33473482    2003       NaN
# 215   WOS:000376684300020               7930336    2015       NaN
# 265   WOS:000264956700003              20687095    2009       3.0
# 277   WOS:000339937700001              73952925    2014       6.0
# ...                   ...                   ...     ...       ...
# 1582  WOS:000166212100001              32739148    2000      10.0
# 1583  WOS:000894965000001              70541596    2022      11.0
# 1584  WOS:000321898300005               6794670    2013       8.0
# 1585  WOS:000392212200010               1259555    2010       NaN
# 1586  WOS:000377962500055              53506649    2016       5.0
#
#      wos_pubdate_online                                         item_title  \
# 32                  NaN  Correlation between videogame mechanics and ex...
# 177                 NaN  Noise in a randomly and sparsely connected exc...
# 215                 NaN  Can Videogames Improve Executive Functioning? ...
# 265                 NaN  Cortical basis of communication: Local computa...
# 277                 NaN  Toward a new cognitive neuroscience: modeling ...
# ...                 ...                                                ...
# 1582                NaN  Reorganization of the human CNS - Neurophysiol...
# 1583                NaN  Virtual Intelligence: A Systematic Review of t...
# 1584                NaN  Action, Outcome, and Value: A Dual-System Fram...
# 1585                NaN  Grid-wide neuroimaging data federation in the ...
# 1586                NaN  A subsequent closed-form description of propag...
#
#      scopus_item_title_non_eng                     first_author  \
# 32                         NaN                  Mondejar, Tania
# 177                        NaN                       Vibert, JF
# 215                        NaN                  Mondejar, Tania
# 265                        NaN              Alexandre, Frederic
# 277                        NaN                   Gramann, Klaus
# ...                        ...                              ...
# 1582                       NaN                       Schalow, G
# 1583                       NaN  Zavala Hernandez, Jesus Gerardo
# 1584                       NaN                   Cushman, Fiery
# 1585                       NaN                   Michel, Franck
# 1586                       NaN              Melendy, Robert. F.
#
#                                 doi        pmid  ... fncr_5_years  \
# 32        10.1016/j.jbi.2016.08.006  27507089.0  ...     1.939175
# 177               10.1117/12.488736         NaN  ...     0.000000
# 215    10.1007/978-3-319-26508-7_20         NaN  ...     0.000000
# 265    10.1016/j.neunet.2009.01.006  19217253.0  ...     0.163626
# 277        10.3389/fnhum.2014.00444  24994978.0  ...     5.445466
# ...                             ...         ...  ...          ...
# 1582                            NaN  11252267.0  ...     0.055891
# 1583       10.3390/brainsci12111552  36421877.0  ...     0.000000
# 1584       10.1177/1088868313495594  23861355.0  ...     3.958603
# 1585  10.3233/978-1-60750-583-9-112  20543431.0  ...     0.737614
# 1586              10.1063/1.4948985         NaN  ...     0.059848
#
#      fncr_all_years                                         hc_3_years  \
# 32         1.706871  {"(\"Computer Science, Interdisciplinary Appli...
# 177        0.000000  {"(Neurosciences,0.0)","(Physiology,0.0)","(Bi...
# 215        0.000000  {"(\"Computer Science, Artificial Intelligence...
# 265        0.050769  {"(\"Computer Science, Artificial Intelligence...
# 277        6.641124         {"(Psychology,1.0)","(Neurosciences,1.0)"}
# ...             ...                                                ...
# 1582       0.048093  {"(Physiology,0.0)","(Biophysics,0.0)","(Bioch...
# 1583       0.000000                            {"(Neurosciences,0.0)"}
# 1584       3.676859                   {"(\"Psychology, Social\",1.0)"}
# 1585       1.644438  {"(Medical Informatics,0.02910798)","(Health C...
# 1586       0.039590  {"(\"Physics, Applied\",0.0)","(Nanoscience & ...
#
#                                              hc_5_years  \
# 32    {"(\"Computer Science, Interdisciplinary Appli...
# 177   {"(Neurosciences,0.0)","(Physiology,0.0)","(Bi...
# 215   {"(\"Computer Science, Artificial Intelligence...
# 265   {"(\"Computer Science, Artificial Intelligence...
# 277          {"(Psychology,1.0)","(Neurosciences,1.0)"}
# ...                                                 ...
# 1582  {"(Physiology,0.0)","(Biophysics,0.0)","(Bioch...
# 1583                            {"(Neurosciences,0.0)"}
# 1584                   {"(\"Psychology, Social\",1.0)"}
# 1585  {"(Medical Informatics,0.0)","(Health Care Sci...
# 1586  {"(\"Physics, Applied\",0.0)","(Nanoscience & ...
#
#                                            hc_all_years  \
# 32    {"(\"Computer Science, Interdisciplinary Appli...
# 177   {"(Neurosciences,0.0)","(Physiology,0.0)","(Bi...
# 215   {"(\"Computer Science, Artificial Intelligence...
# 265   {"(\"Computer Science, Artificial Intelligence...
# 277          {"(Psychology,1.0)","(Neurosciences,1.0)"}
# ...                                                 ...
# 1582  {"(Physiology,0.0)","(Biophysics,0.0)","(Bioch...
# 1583                            {"(Neurosciences,0.0)"}
# 1584                   {"(\"Psychology, Social\",1.0)"}
# 1585  {"(Medical Informatics,0.0)","(Health Care Sci...
# 1586  {"(\"Physics, Applied\",0.0)","(Nanoscience & ...
#
#                    oa_status oa_url scopus_oa_licence  \
# 32                  {bronze}    NaN               NaN
# 177                      NaN    NaN               NaN
# 215                      NaN    NaN               NaN
# 265        {green_submitted}    NaN               NaN
# 277   {gold,green_published}    NaN               NaN
# ...                      ...    ...               ...
# 1582                     NaN    NaN               NaN
# 1583  {gold,green_published}    NaN               NaN
# 1584                     NaN    NaN               NaN
# 1585                     NaN    NaN               NaN
# 1586                  {gold}    NaN               NaN
#
#                                                abstract  \
# 32    {"This paper addresses a different point of vi...
# 177   {"The mechanisms involved in respiratory rhyth...
# 215   {"Nowadays, we are living a different use and ...
# 265   {"Human communication emerges from cortical pr...
# 277                                                 NaN
# ...                                                 ...
# 1582  {"The key strategies on which the discovery of...
# 1583  {"The functioning of the brain has been a comp...
# 1584  {"Dual-system approaches to psychology explain...
# 1585  {"Grid technologies are appealing to deal with...
# 1586  {"I recently introduced a closed-form descript...
#
#                                             title_lower
# 32    correlation between videogame mechanics and ex...
# 177   noise in a randomly and sparsely connected exc...
# 215   can videogames improve executive functioning? ...
# 265   cortical basis of communication: local computa...
# 277   toward a new cognitive neuroscience: modeling ...
# ...                                                 ...
# 1582  reorganization of the human cns - neurophysiol...
# 1583  virtual intelligence: a systematic review of t...
# 1584  action, outcome, and value: a dual-system fram...
# 1585  grid-wide neuroimaging data federation in the ...
# 1586  a subsequent closed-form description of propag...
#
# [70 rows x 52 columns]

# %%
dup_counts = cn_full.groupby('title_lower').size().reset_index(name='count')

# Filter rows where count > 1 to get duplicates
dup_overview = dup_counts[dup_counts['count'] > 1].sort_values(by='count', ascending=False)

dup_overview
# Out:
#                                             title_lower  count
# 151   a subsequent closed-form description of propag...      2
# 1210  reorganization of the human cns - neurophysiol...      2
# 953   modelling honeybee visual guidance in a 3-d en...      2
# 976   multi-site voxel-based morphometry - not quite...      2
# 1037  neuronal circuit-based computer modeling as a ...      2
# 1042  neuronal reorganization through oscillator for...      2
# 1049  neuroplasticity and the brain connectome: what...      2
# 1057  noise in a randomly and sparsely connected exc...      2
# 1219  resolving the biophysics of axon transmembrane...      2
# 815   integrating fmri and single-cell data of visua...      2
# 1293  spikenet: real-time visual processing with one...      2
# 1296       spiking neuron model approximation using gep      2
# 1326  structures in physics and neuroscience structu...      2
# 1415  the portuguese bing network: towards a brain i...      2
# 1431     the three cultures of computational psychiatry      2
# 1462  toward a new cognitive neuroscience: modeling ...      2
# 830   introduction to machine learning for brain ima...      2
# 789   improved izhikevich neurons for spiking neural...      2
# 175   action, outcome, and value: a dual-system fram...      2
# 451                   computational physics of the mind      2
# 191   age is not necessarily aging: another step tow...      2
# 228   analysis of eeg frequency bands during typical...      2
# 287               bayesian brain: can we model emotion?      2
# 300   beyond traditional approaches to understanding...      2
# 315    biomedical wellness challenges and opportunities      2
# 352   can videogames improve executive functioning? ...      2
# 452                            computational psychiatry      2
# 768   human-scale brain simulation via supercomputer...      2
# 485   correlation between videogame mechanics and ex...      2
# 486   cortical basis of communication: local computa...      2
# 553   dynamical complexity in cognitive neural networks      2
# 569   editorial: hierarchical object representations...      2
# 607   episodix: a serious game to detect cognitive i...      2
# 734   grid-wide neuroimaging data federation in the ...      2
# 1525  virtual intelligence: a systematic review of t...      2

# %% [markdown]
# Check for generic titles that could in fact be different publications instead of only duplicates

# %%
#cn_full[cn_full['title_lower'] == 'computational psychiatry'] # different articles!!
#cn_full[cn_full['title_lower'] == 'computational physics of the mind'] # same article
#cn_full[cn_full['title_lower'] == 'dynamical complexity in cognitive neural networks'] # same article
#cn_full[cn_full['title_lower'] == 'introduction to machine learning for brain imaging'] # same article

# %% [markdown]
# Removal of all duplicate titles except the ones with the title "computational psychiatry"

# %%
# Find rows with 'title_lower' as "computational psychiatry" and remove duplicates while always keeping the first occurrence
comppsy = cn_full[cn_full['title_lower'] == 'computational psychiatry']
filtered_cn_full = cn_full[(cn_full['title_lower'] != 'computational psychiatry')].drop_duplicates(subset='title_lower', keep='first') # Exclude rows with 'title_lower' as "computational psychiatry"!

# "Remerge" the filtered df and the "computational psychiatry" rows
cn_full = pd.concat([filtered_cn_full, comppsy]).sort_index()

cn_full.shape # (1553, 52)
# Out:
# (1553, 52)

# %% [markdown]
# Clean authors column

# %%
cn_full.head(20)
# Out:
#                 item_id fk_repository_history pubyear  pubmonth  \
# 0   WOS:000173024600148              19474708    2001       NaN
# 1   WOS:000225749600004              25952386    2004      11.0
# 2   WOS:000225975400002              52560831    2005       1.0
# 3   WOS:000232166100016              51224037    2005       9.0
# 4   WOS:000236717500009               5616690    2006       4.0
# 5   WOS:000237873900039               9554784    2006       6.0
# 6   WOS:000250443000004              51248799    2007      10.0
# 7   WOS:000256823000012              40880006    2008       7.0
# 8   WOS:000257643500013              41399807    2008       NaN
# 9   WOS:000263798900003              27289522    2009       4.0
# 10  WOS:000268757400010              19973651    2009       8.0
# 11  WOS:000276945700016                549327    2010       NaN
# 12  WOS:000286843200061               5095168    2010       NaN
# 13  WOS:000288567700007               3760996    2011       3.0
# 14  WOS:000292409800005               4382658    2011       8.0
# 15  WOS:000296343800005              11183217    2011       NaN
# 16  WOS:000297861100001              42870483    2012       4.0
# 17  WOS:000299100900007              14305885    2011       NaN
# 18  WOS:000304239600004              39759506    2012       5.0
# 19  WOS:000322508900002                551138    2013       7.0
#
#    wos_pubdate_online                                         item_title  \
# 0                 NaN  Extracting slow subspaces from natural videos ...
# 1                 NaN  Models of the subthalamic nucleus - The import...
# 2                 NaN  Synaptic and spiking dynamics underlying rewar...
# 3                 NaN      Rapid reshaping of human motor generalization
# 4                 NaN  Some insights into computational models of (pa...
# 5                 NaN  Reward-biased probabilistic decision-making: M...
# 6                 NaN  Automatic generation of cognitive theories usi...
# 7                 NaN  Differences between the channels, currents and...
# 8                 NaN  Episodes in space: A modeling study of hippoca...
# 9                 NaN  Nonlinear dynamics and chaos methods in neurod...
# 10                NaN  Biologically Inspired Mobile Robot Vision Loca...
# 11                NaN  COMPARISON OF MEMBRANE PROPERTY ABNORMALITIES ...
# 12                NaN  Simulation of How Neuromodulation Influences C...
# 13                NaN  THE MYELIN SHEATH AQUEOUS LAYERS IMPROVE THE M...
# 14                NaN  Are computational models of any use to psychia...
# 15                NaN  MentalSquares: A generic bipolar Support Vecto...
# 16                NaN  Towards truly human-level intelligence in arti...
# 17                NaN                  Constructive Cortical Computation
# 18                NaN       The eMOSAIC model for humanoid robot control
# 19                NaN  The advantage of flexible neuronal tunings in ...
#
#    scopus_item_title_non_eng             first_author  \
# 0                        NaN                Kayser, C
# 1                        NaN               Gillies, A
# 2                        NaN                  Deco, G
# 3                        NaN          Thoroughman, KA
# 4                        NaN           Suffczynski, P
# 5                        NaN                 Marti, D
# 6                        NaN  Frias-Martinez, Enrique
# 7                        NaN     Stephanova, Diana I.
# 8                        NaN        Ujfalussy, Balazs
# 9                        NaN        Ivancevic, Tijana
# 10                       NaN       Siagian, Christian
# 11                       NaN        Stephanova, Diana
# 12                       NaN         Zaldivar, Andrew
# 13                       NaN        Stephanova, D. I.
# 14                       NaN      Huys, Quentin J. M.
# 15                       NaN           Zhang, Wen-Ran
# 16                       NaN           de Kamps, Marc
# 17                       NaN          Douglas, Rodney
# 18                       NaN       Sugimoto, Norikazu
# 19                       NaN   Marongelli, Ellisha N.
#
#                                 doi        pmid  ... fncr_5_years  \
# 0                               NaN         NaN  ...     2.503746
# 1   10.1016/j.medengphy.2004.06.003  15564109.0  ...     0.616486
# 2             10.1093/cercor/bhh103  15238449.0  ...     2.263256
# 3    10.1523/jneurosci.1771-05.2005  16192385.0  ...     0.856367
# 4         10.1109/jproc.2006.871773         NaN  ...     0.305249
# 5      10.1016/j.neucom.2005.12.069         NaN  ...     0.661564
# 6         10.1007/s11023-007-9070-6         NaN  ...     0.516117
# 7         10.1007/s00249-008-0284-1  18286274.0  ...     0.404544
# 8                               NaN         NaN  ...     6.377715
# 9         10.1007/s11071-008-9376-9         NaN  ...     0.721852
# 10         10.1109/tro.2009.2022424         NaN  ...     4.839198
# 11                              NaN         NaN  ...     0.062246
# 12                              NaN         NaN  ...     2.911078
# 13        10.1142/s0219635211002646  21425485.0  ...     0.120312
# 14     10.1016/j.neunet.2011.03.001  21459554.0  ...     1.425267
# 15        10.1504/ijdmb.2011.043034  22145533.0  ...     0.170183
# 16     10.1016/j.cogsys.2011.01.003         NaN  ...     0.079973
# 17      10.1016/j.procs.2011.12.008         NaN  ...     0.000000
# 18     10.1016/j.neunet.2012.01.002  22366503.0  ...     0.746138
# 19         10.3389/fncom.2013.00100  23888141.0  ...     0.000000
#
#    fncr_all_years                                         hc_3_years  \
# 0        0.916440  {"(\"Computer Science, Artificial Intelligence...
# 1        0.683756              {"(\"Engineering, Biomedical\",0.0)"}
# 2        1.119644                            {"(Neurosciences,1.0)"}
# 3        1.360798                            {"(Neurosciences,0.0)"}
# 4        0.229523  {"(\"Engineering, Electrical & Electronic\",0....
# 5        0.224316  {"(\"Computer Science, Artificial Intelligence...
# 6        0.251423  {"(\"Computer Science, Artificial Intelligence...
# 7        0.200330                               {"(Biophysics,0.0)"}
# 8        1.717540  {"(\"Computer Science, Artificial Intelligence...
# 9        0.330845  {"(\"Engineering, Mechanical\",0.0)","(Mechani...
# 10       3.866360                                 {"(Robotics,1.0)"}
# 11       0.032984               {"(Multidisciplinary Sciences,0.0)"}
# 12       1.282651  {"(\"Computer Science, Artificial Intelligence...
# 13       0.047760                            {"(Neurosciences,0.0)"}
# 14       1.517009  {"(\"Computer Science, Artificial Intelligence...
# 15       0.868313     {"(Mathematical & Computational Biology,0.0)"}
# 16       0.062261  {"(\"Computer Science, Artificial Intelligence...
# 17       0.000000  {"(\"Computer Science, Theory & Methods\",0.0)...
# 18       0.485893  {"(\"Computer Science, Artificial Intelligence...
# 19       0.067849  {"(Neurosciences,0.0)","(Mathematical & Comput...
#
#                                            hc_5_years  \
# 0   {"(\"Computer Science, Artificial Intelligence...
# 1               {"(\"Engineering, Biomedical\",0.0)"}
# 2                             {"(Neurosciences,1.0)"}
# 3                             {"(Neurosciences,0.0)"}
# 4   {"(\"Engineering, Electrical & Electronic\",0....
# 5   {"(\"Computer Science, Artificial Intelligence...
# 6   {"(\"Computer Science, Artificial Intelligence...
# 7                                {"(Biophysics,0.0)"}
# 8   {"(\"Computer Science, Artificial Intelligence...
# 9   {"(\"Engineering, Mechanical\",0.0)","(Mechani...
# 10                                 {"(Robotics,1.0)"}
# 11               {"(Multidisciplinary Sciences,0.0)"}
# 12  {"(\"Computer Science, Artificial Intelligence...
# 13                            {"(Neurosciences,0.0)"}
# 14  {"(\"Computer Science, Artificial Intelligence...
# 15     {"(Mathematical & Computational Biology,0.0)"}
# 16  {"(\"Computer Science, Artificial Intelligence...
# 17  {"(\"Computer Science, Theory & Methods\",0.0)...
# 18  {"(\"Computer Science, Artificial Intelligence...
# 19  {"(Neurosciences,0.0)","(Mathematical & Comput...
#
#                                          hc_all_years  \
# 0   {"(\"Computer Science, Artificial Intelligence...
# 1               {"(\"Engineering, Biomedical\",0.0)"}
# 2                             {"(Neurosciences,0.0)"}
# 3                             {"(Neurosciences,0.0)"}
# 4   {"(\"Engineering, Electrical & Electronic\",0....
# 5   {"(\"Computer Science, Artificial Intelligence...
# 6   {"(\"Computer Science, Artificial Intelligence...
# 7                                {"(Biophysics,0.0)"}
# 8   {"(\"Computer Science, Artificial Intelligence...
# 9   {"(\"Engineering, Mechanical\",0.0)","(Mechani...
# 10                                 {"(Robotics,1.0)"}
# 11               {"(Multidisciplinary Sciences,0.0)"}
# 12  {"(\"Computer Science, Artificial Intelligence...
# 13                            {"(Neurosciences,0.0)"}
# 14  {"(\"Computer Science, Artificial Intelligence...
# 15     {"(Mathematical & Computational Biology,0.0)"}
# 16  {"(\"Computer Science, Artificial Intelligence...
# 17  {"(\"Computer Science, Theory & Methods\",0.0)...
# 18  {"(\"Computer Science, Artificial Intelligence...
# 19  {"(Neurosciences,0.0)","(Mathematical & Comput...
#
#                                    oa_status oa_url scopus_oa_licence  \
# 0                                        NaN    NaN               NaN
# 1                                        NaN    NaN               NaN
# 2                   {green_submitted,bronze}    NaN               NaN
# 3   {green_published,bronze,green_submitted}    NaN               NaN
# 4                          {green_submitted}    NaN               NaN
# 5                                        NaN    NaN               NaN
# 6                          {green_submitted}    NaN               NaN
# 7                                        NaN    NaN               NaN
# 8                                        NaN    NaN               NaN
# 9                                        NaN    NaN               NaN
# 10                         {green_submitted}    NaN               NaN
# 11                                       NaN    NaN               NaN
# 12                                       NaN    NaN               NaN
# 13                                       NaN    NaN               NaN
# 14                                       NaN    NaN               NaN
# 15                                       NaN    NaN               NaN
# 16                                       NaN    NaN               NaN
# 17                                    {gold}    NaN               NaN
# 18                                       NaN    NaN               NaN
# 19                    {green_published,gold}    NaN               NaN
#
#                                              abstract  \
# 0   {"Natural videos obtained from a camera mounte...
# 1   {"A coherent set of models is presented that p...
# 2   {"Cognitive and emotional flexibility involve ...
# 3   {"People routinely learn how to manipulate new...
# 4   {"The amount of experimental data concerning p...
# 5   {"In this work we study the basic competitive ...
# 6   {"Cognitive neuroscience is the branch of neur...
# 7   {"To clarify the differences between the mecha...
# 8   {"A computer model of learning and representin...
# 9   {"In this paper, we review modern nonlinear dy...
# 10  {"We present a robot localization system using...
# 11  {"This paper compares the membrane properties ...
# 12  {"Neuromodulators can have a strong effect on ...
# 13  {"Recently, patients with chronic demyelinatin...
# 14  {"Mathematically rigorous descriptions of key ...
# 15  {"MentalSquares (MSQs) - an equilibrium- based...
# 16  {"Despite the fact that there are now a large ...
# 17                                                NaN
# 18  {"In this study, we propose an extension of th...
# 19  {"Human motor adaptation to novel environments...
#
#                                           title_lower
# 0   extracting slow subspaces from natural videos ...
# 1   models of the subthalamic nucleus - the import...
# 2   synaptic and spiking dynamics underlying rewar...
# 3       rapid reshaping of human motor generalization
# 4   some insights into computational models of (pa...
# 5   reward-biased probabilistic decision-making: m...
# 6   automatic generation of cognitive theories usi...
# 7   differences between the channels, currents and...
# 8   episodes in space: a modeling study of hippoca...
# 9   nonlinear dynamics and chaos methods in neurod...
# 10  biologically inspired mobile robot vision loca...
# 11  comparison of membrane property abnormalities ...
# 12  simulation of how neuromodulation influences c...
# 13  the myelin sheath aqueous layers improve the m...
# 14  are computational models of any use to psychia...
# 15  mentalsquares: a generic bipolar support vecto...
# 16  towards truly human-level intelligence in arti...
# 17                  constructive cortical computation
# 18       the emosaic model for humanoid robot control
# 19  the advantage of flexible neuronal tunings in ...
#
# [20 rows x 52 columns]

# %% [markdown]
# Save clean dataframe of citing articles

# %%
# Save clean data to csv
cn_full.to_csv('cn_items_clean.csv', index=False)

list_item_ids = cn_full['item_id'].tolist()
with open('list_item_ids.txt', 'w') as file: # "Context manager" saves item ids to txt file
    for item in list_item_ids:
        file.write(str(item) + '\n')

# Save item ids to csv for sql data base search of references
item_ids_df = pd.DataFrame(list_item_ids, columns=['item_id'])
item_ids_df.to_csv('item_ids.csv', index=False)

# %%
# Convert list to comma-separated string with quoted values for the KB sql query of references
wos_ids = ', '.join(f"'{id_}'" for id_ in list_item_ids)
print(wos_ids) # if needed for sql query
# Out:
# 'WOS:000173024600148', 'WOS:000225749600004', 'WOS:000225975400002', 'WOS:000232166100016', 'WOS:000236717500009', 'WOS:000237873900039', 'WOS:000250443000004', 'WOS:000256823000012', 'WOS:000257643500013', 'WOS:000263798900003', 'WOS:000268757400010', 'WOS:000276945700016', 'WOS:000286843200061', 'WOS:000288567700007', 'WOS:000292409800005', 'WOS:000296343800005', 'WOS:000297861100001', 'WOS:000299100900007', 'WOS:000304239600004', 'WOS:000322508900002', 'WOS:000341844800008', 'WOS:000342695200038', 'WOS:000345024600003', 'WOS:000347110600012', 'WOS:000348104800001', 'WOS:000358125000022', 'WOS:000361488600009', 'WOS:000370525500003', 'WOS:000370730602073', 'WOS:000371496600019', 'WOS:000373638600017', 'WOS:000383917600738', 'WOS:000389557000015', 'WOS:000395099500043', 'WOS:000406352000010', 'WOS:000418280300001', 'WOS:000419184600003', 'WOS:000425272400001', 'WOS:000427645500088', 'WOS:000430096800002', 'WOS:000437324100001', 'WOS:000449695000021', 'WOS:000455682100228', 'WOS:000471305100001', 'WOS:000493944500005', 'WOS:000500919900008', 'WOS:000511448500008', 'WOS:000524679600058', 'WOS:000530095200142', 'WOS:000531101900007', 'WOS:000566830900003', 'WOS:000604917900005', 'WOS:000626021404086', 'WOS:000664067300001', 'WOS:000733162000001', 'WOS:000748450800001', 'WOS:000813323800001', 'WOS:000867069500001', 'WOS:000890869500001', 'WOS:000914969500001', 'WOS:000220065400001', 'WOS:000241579500001', 'WOS:000252257400004', 'WOS:000261028300004', 'WOS:000265684700014', 'WOS:000276266400010', 'WOS:000278535100014', 'WOS:000286160600019', 'WOS:000292776200003', 'WOS:000309318200034', 'WOS:000309341301078', 'WOS:000310192900004', 'WOS:000313227900003', 'WOS:000316056900014', 'WOS:000344767600001', 'WOS:000345905002083', 'WOS:000348207000001', 'WOS:000356777000001', 'WOS:000357303800007', 'WOS:000357823900001', 'WOS:000368635600002', 'WOS:000380505200002', 'WOS:000383223100043', 'WOS:000384570200006', 'WOS:000390706300064', 'WOS:000393794500001', 'WOS:000400348701111', 'WOS:000406029900009', 'WOS:000406504700001', 'WOS:000430129400001', 'WOS:000444235500011', 'WOS:000448676500005', 'WOS:000449447500002', 'WOS:000455034000009', 'WOS:000455194300001', 'WOS:000459740300017', 'WOS:000467491000006', 'WOS:000485140300072', 'WOS:000530893801044', 'WOS:000561609100001', 'WOS:000596843300001', 'WOS:000645683800079', 'WOS:000647460100001', 'WOS:000687266500010', 'WOS:000732342900001', 'WOS:000752300400001', 'WOS:000754069400001', 'WOS:000769071200017', 'WOS:000844529400052', 'WOS:000876518600001', 'WOS:000879508900001', 'WOS:A1993KR72400022', 'WOS:A1996VM37900018', 'WOS:000169129200224', 'WOS:000178871900233', 'WOS:000209207100026', 'WOS:000209207300027', 'WOS:000220265600001', 'WOS:000232721400006', 'WOS:000241382300008', 'WOS:000247641900060', 'WOS:000255097100002', 'WOS:000276344300006', 'WOS:000283685800007', 'WOS:000284104400003', 'WOS:000288499700001', 'WOS:000295220400001', 'WOS:000302237300013', 'WOS:000306641100061', 'WOS:000316056900008', 'WOS:000316056900012', 'WOS:000335859300196', 'WOS:000341844800002', 'WOS:000380323800002', 'WOS:000397326500005', 'WOS:000408339000002', 'WOS:000408732000005', 'WOS:000419790300008', 'WOS:000425314200001', 'WOS:000426897300005', 'WOS:000426982100013', 'WOS:000431896000015', 'WOS:000444235500012', 'WOS:000464378400003', 'WOS:000466871400003', 'WOS:000472661000767', 'WOS:000498859500013', 'WOS:000525321000021', 'WOS:000534690500001', 'WOS:000535911100004', 'WOS:000538131700003', 'WOS:000539295700001', 'WOS:000557303500011', 'WOS:000564232800001', 'WOS:000589793800001', 'WOS:000597437600001', 'WOS:000624069500003', 'WOS:000626021405094', 'WOS:000626471200001', 'WOS:000638076500015', 'WOS:000656671300001', 'WOS:000682772901032', 'WOS:000702043900031', 'WOS:000704127700001', 'WOS:000720635500001', 'WOS:000725511402116', 'WOS:000733527400001', 'WOS:000808100700080', 'WOS:000860218400001', 'WOS:000879811400001', 'WOS:000305415000005', 'WOS:000898549100009', 'WOS:000083679100111', 'WOS:000167812500015' ...

# %% [markdown]
# After checking for duplicates, we can assume to have a clean dataset with 1553 articles. We can now start with the preliminary analysis.
